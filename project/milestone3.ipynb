# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
superstore_data = pd.read_csv("/Users/theranmeadows/Desktop/Bellevue University/dsc630predictiveAnalytics/project/superstore - data - superstore - superstore.csv")
superstore_data.head()
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  2 Order.Date        Order.ID  ...   Segment Ship.Date  \
# 0       0.0     US  1    00:00.0  CA-2011-130813  ...  Consumer   00:00.0
# 1       0.0     US  1    00:00.0  CA-2011-148614  ...  Consumer   00:00.0
# 2       0.0     US  1    00:00.0  CA-2011-118962  ...  Consumer   00:00.0
# 3       0.0     US  1    00:00.0  CA-2011-118962  ...  Consumer   00:00.0
# 4       0.0     US  1    00:00.0  CA-2011-146969  ...  Consumer   00:00.0
#
# ...

# %%
superstore_grouped = superstore_data.groupby("Category")
category_sales = superstore_grouped['Profit'].sum()

# %%
cat_sales_data = [['Furniture', 285204.72], ['Office Supplies', 518473.83], ['Technology', 663778.73]]
category_sales_df = pd.DataFrame(cat_sales_data, columns=['Category', 'Total Profit'])

# %%
category_sales_df.plot(x = 'Category', y = 'Total Profit', kind = 'bar')
plt.title("Total Proft by Category")
plt.xlabel('Category')
plt.ylabel("Total Profit")
# Out:
# Text(0, 0.5, 'Total Profit')

# %%
category_sales_df
# Out:
#           Category  Total Profit
# 0        Furniture     285204.72
# 1  Office Supplies     518473.83
# 2       Technology     663778.73

# %%
tech_df = superstore_data.loc[superstore_data['Category'] == 'Technology']
tech_df.head()
# Out:
#          Category       City  Country Customer.ID    Customer.Name  Discount  \
# 19209  Technology  Vinnytsya  Ukraine    RD-99002      Ruben Dartt       0.0
# 19210  Technology  Marseille   France   JW-160752       Julia West       0.0
# 19211  Technology  São Paulo   Brazil   CR-126253      Corey Roper       0.0
# 19212  Technology     Naples    Italy   JC-161052  Julie Creighton       0.0
# 19213  Technology   Ludhiana    India   AG-104951  Andrew Gjertsen       0.0
#
#       Market  2 Order.Date         Order.ID  ...      Segment Ship.Date  \
# 19209   EMEA  1    00:00.0     UP-2011-3730  ...     Consumer   00:00.0
# 19210     EU  1    00:00.0  ES-2011-3376060  ...     Consumer   00:00.0
# 19211  LATAM  1    00:00.0   MX-2011-148033  ...  Home Office   00:00.0
# 19212     EU  1    00:00.0  IT-2011-1780558  ...    Corporate   00:00.0
# 19213   APAC  1    00:00.0    IN-2011-74994  ...    Corporate   00:00.0
#
# ...

# %%
tech_grouped = tech_df.groupby("Sub.Category")
tech_sales = tech_grouped['Profit'].sum()

# %%
tech_sales_df = [['Accessories', 129626.30], ['Copiers', 258567.55], ['Machines', 58867.87], ['Phones', 216717.01]]
technology_sales_df = pd.DataFrame(tech_sales_df, columns=['Sub.Category', 'Total Profit'])

# %%
technology_sales_df
# Out:
#   Sub.Category  Total Profit
# 0  Accessories     129626.30
# 1      Copiers     258567.55
# 2     Machines      58867.87
# 3       Phones     216717.01

# %%
technology_sales_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 technology_sales_df
#
# NameError: name 'technology_sales_df' is not defined

# %%
technology_sales_df.plot(x = 'Sub.Category', y = 'Total Profit', kind = 'bar')
plt.title("Total Proft by Sub.Category: Technology")
plt.xlabel('Category')
plt.ylabel("Total Profit")
# Out:
# Text(0, 0.5, 'Total Profit')

# %%
office_supp_df = superstore_data.loc[superstore_data['Category'] == 'Office Supplies']
office_supp_df.head()
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  2 Order.Date        Order.ID  ... Sales   Segment  \
# 0       0.0     US  1    00:00.0  CA-2011-130813  ...    19  Consumer
# 1       0.0     US  1    00:00.0  CA-2011-148614  ...    19  Consumer
# 2       0.0     US  1    00:00.0  CA-2011-118962  ...    21  Consumer
# 3       0.0     US  1    00:00.0  CA-2011-118962  ...   111  Consumer
# 4       0.0     US  1    00:00.0  CA-2011-146969  ...     6  Consumer
#
#   Ship.Date       Ship.Mode  Shipping.Cost       State  Sub.Category  Year  \
# ...

# %%
offsupp_grouped = office_supp_df.groupby("Sub.Category")
office_sales = offsupp_grouped['Profit'].sum()
office_sales
# Out:
# Sub.Category
# Appliances    141680.5894
# Art            57953.9109
# Binders        72449.8460
# Envelopes      29601.1163
# Fasteners      11525.4241
# Labels         15010.5120
# Paper          59207.6827
# Storage       108461.4898
# Supplies       22583.2631
# Name: Profit, dtype: float64

# %%
office_sales_df = [['Appliances', 141680.5894],
                   ['Art', 57953.9109], 
                   ['Binders', 72449.8460], 
                   ['Envelopes', 29601.1163], 
                   ['Fasteners', 11525.4241], 
                   ['Labels', 15010.5120], 
                   ['Paper', 59207.6827], 
                   ['Storage', 108461.4898], 
                   ['Supplies', 22583.2631]]

office_supplies_sales_df = pd.DataFrame(office_sales_df, columns=['Sub.Category', 'Total Profit'])

# %%
office_supplies_sales_df.plot(x = 'Sub.Category', y = 'Total Profit', kind = 'bar')
plt.title("Total Proft by Sub.Category: Office Supplies")
plt.xlabel('Category')
plt.ylabel("Total Profit")
# Out:
# Text(0, 0.5, 'Total Profit')

# %%
furniture_df = superstore_data.loc[superstore_data['Category'] == 'Furniture']
furniture_df.head()
# Out:
#         Category         City      Country Customer.ID   Customer.Name  \
# 21096  Furniture  Paraparaumu  New Zealand   TS-216101    Troy Staebel
# 21097  Furniture       Tehran         Iran   SZ-100352      Sam Zeldin
# 21098  Furniture   Phnom Penh     Cambodia   SC-206801   Steve Carroll
# 21099  Furniture       Galati      Romania    CM-27152  Craig Molinari
# 21100  Furniture        Haifa       Israel   TG-116403    Trudy Glocke
#
#        Discount Market  2 Order.Date       Order.ID  ... Sales      Segment  \
# 21096       0.0   APAC  1    00:00.0  IN-2011-81833  ...  1917     Consumer
# 21097       0.0   EMEA  1    00:00.0    IR-2011-360  ...   490  Home Office
# 21098       0.0   APAC  1    00:00.0  IN-2011-30306  ...  1330  Home Office
# 21099       0.0   EMEA  1    00:00.0   RO-2011-9170  ...   336    Corporate
# 21100       0.0   EMEA  1    00:00.0   IS-2011-7780  ...   317     Consumer
#
#       Ship.Date       Ship.Mode  Shipping.Cost       State  Sub.Category  \
# ...

# %%
furniture_grouped = furniture_df.groupby("Sub.Category")
furniture_sales = furniture_grouped['Profit'].sum()
furniture_sales
# Out:
# Sub.Category
# Bookcases      161924.4195
# Chairs         140396.2675
# Furnishings     46967.4255
# Tables         -64083.3887
# Name: Profit, dtype: float64

# %%
furniture_sales_data = [['Bookcases', 161924.4195],
                   ['Chairs', 140396.2675], 
                   ['Furnishings', 46967.4255], 
                   ['Tables', -64083.3887]]

furniture_sales_df = pd.DataFrame(furniture_sales_data, columns=['Sub.Category', 'Total Profit'])

# %%
furniture_sales_df.plot(x = 'Sub.Category', y = 'Total Profit', kind = 'bar')
plt.title("Total Proft by Sub.Category: Furniture")
plt.xlabel('Category')
plt.ylabel("Total Profit")
# Out:
# Text(0, 0.5, 'Total Profit')
