# %% [markdown]
# # Week 1: Python Refresher

# %% [markdown]
# ### Write a summary of your data and identify at least two questions to explore visually with your data.

# %% [markdown]
# The Aircraft Wildlife Strikes 1990-2023 data set is a data set that contains over 30 years of airplanes strikes that involved wildlife. It was compiled by the Federal Aviation Administration and contains data such as Date, Airport, Damage Level, and even the species of wildlife that was hit.
#
# Two questions I would like to answer about this data set is:
# 1) What was the most common species among the airplane strikes?
# 2) What year had the most strikes?

# %%
# Load libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# load the data
crash_data = pd.read_csv('/Users/theranmeadows/Desktop/dsc630predictiveAnalytics/week1/STRIKE_REPORTS.csv')
crash_data.columns
# Out:
# /var/folders/w7/y9m37qn9069d8533jsyhz90r0000gn/T/ipykernel_11558/4038036415.py:2: DtypeWarning: Columns (18,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   crash_data = pd.read_csv('/Users/theranmeadows/Desktop/dsc630predictiveAnalytics/week1/STRIKE_REPORTS.csv')
# Index(['INDEX_NR', 'INCIDENT_DATE', 'INCIDENT_MONTH', 'INCIDENT_YEAR', 'TIME',
#        'TIME_OF_DAY', 'AIRPORT_ID', 'AIRPORT', 'LATITUDE', 'LONGITUDE',
#        'RUNWAY', 'STATE', 'FAAREGION', 'LOCATION', 'ENROUTE_STATE', 'OPID',
#        'OPERATOR', 'REG', 'FLT', 'AIRCRAFT', 'AMA', 'AMO', 'EMA', 'EMO',
#        'AC_CLASS', 'AC_MASS', 'TYPE_ENG', 'NUM_ENGS', 'ENG_1_POS', 'ENG_2_POS',
#        'ENG_3_POS', 'ENG_4_POS', 'PHASE_OF_FLIGHT', 'HEIGHT', 'SPEED',
#        'DISTANCE', 'SKY', 'PRECIPITATION', 'AOS', 'COST_REPAIRS', 'COST_OTHER',
#        'COST_REPAIRS_INFL_ADJ', 'COST_OTHER_INFL_ADJ', 'INGESTED_OTHER',
#        'INDICATED_DAMAGE', 'DAMAGE_LEVEL', 'STR_RAD', 'DAM_RAD',
# ...

# %%
crash_data.head()
# Out:
#    INDEX_NR INCIDENT_DATE  INCIDENT_MONTH  INCIDENT_YEAR TIME TIME_OF_DAY  \
# 0    608242     6/22/1996               6           1996  NaN         NaN
# 1    608243     6/26/1996               6           1996  NaN         NaN
# 2    608244      7/1/1996               7           1996  NaN         NaN
# 3    608245      7/1/1996               7           1996  NaN         NaN
# 4    608246      7/1/1996               7           1996  NaN         NaN
#
#   AIRPORT_ID                      AIRPORT  LATITUDE  LONGITUDE  ...    SIZE  \
# 0       KSMF              SACRAMENTO INTL  38.69542 -121.59077  ...  Medium
# 1       KDEN          DENVER INTL AIRPORT  39.85841 -104.66700  ...  Medium
# 2       KOMA              EPPLEY AIRFIELD  41.30252  -95.89417  ...  Medium
# 3       KIAD  WASHINGTON DULLES INTL ARPT  38.94453  -77.45581  ...  Medium
# 4       KLGA              LA GUARDIA ARPT  40.77724  -73.87261  ...  Medium
#
# ...

# %% [markdown]
# ### Create a histogram or bar graph from your data.

# %%
count = crash_data['SPECIES'].value_counts().head(10)
count.head()
# Out:
# SPECIES
# Unknown bird - small     48901
# Unknown bird - medium    38259
# Unknown bird             24839
# Mourning dove            14578
# Barn swallow              9679
# Name: count, dtype: int64

# %%
count.plot(kind = 'bar')
plt.title('Species')
plt.xlabel('Species')
plt.ylabel('Number of Strikes')
plt.show()

# %% [markdown]
# ### Create a boxplot from your data.

# %%
plt.boxplot(crash_data['INCIDENT_YEAR'])
plt.title('Strikes by Year')
plt.show()

# %% [markdown]
# ### Create a bivariate plot from your data.

# %%
crash_data.plot(kind = 'scatter', x = 'INCIDENT_YEAR', y = 'NR_INJURIES')
# Out:
# <Axes: xlabel='INCIDENT_YEAR', ylabel='NR_INJURIES'>

# %% [markdown]
# ### Create any additional visualizations that will help to answer the question(s) you want to answer.

# %%
plt.hist(crash_data['INCIDENT_YEAR'])
plt.title('Year')
plt.xlabel('Year')
plt.ylabel('Count of Strikes')
plt.show()

# %% [markdown]
# ### Summarize your results and make a conclusion. Explain how you arrived at this conclusion and how your visualizations support your conclusion.

# %% [markdown]
# It would seem that most strikes will involve some unknown small bird of all things. The fact that it is not identified is not surprising considering that a small bird would be hard enough to see and much less, correctly identify.
#
# It would also appear that bird strikes increase as time goes on. This may mean that there are just more aircrafts in the air thatn there were back then.
